# %% [markdown]
# ##### import the titanic dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
titanic=pd.read_csv(r"C:\Users\DELL\Untitled Folder\IBM_Python_exercises\titanic.csv")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0      man        True  NaN  Southampton    no  False          NaN
# 1    woman       False    C    Cherbourg   yes  False          NaN
# 2    woman       False  NaN  Southampton   yes   True          NaN
# 3    woman       False    C  Southampton   yes  False          NaN
# 4      man        True  NaN  Southampton    no   True          NaN
# ..     ...         ...  ...          ...   ...    ...          ...
# 886    man        True  NaN  Southampton    no   True          NaN
# 887  woman       False    B  Southampton   yes   True          NaN
# 888  woman       False  NaN  Southampton    no  False          NaN
# 889    man        True    C    Cherbourg   yes   True          NaN
# 890    man        True  NaN   Queenstown    no   True          NaN
#
# [891 rows x 16 columns]

# %% [markdown]
# ##### 1. Write a Python program to display a bar chart of the fare of class.

# %%
### code here
sns.barplot(x='sex',y='survived',data=titanic)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %%
import seaborn as sns

titanic['Fare_Range'] = pd.qcut(titanic['fare'], 4)
sns.barplot(x ='Fare_Range', y ='survived',
data = titanic)
# Out:
# <AxesSubplot:xlabel='Fare_Range', ylabel='survived'>

# %% [markdown]
# ###### 2. Write a Python program to display a horizontal bar chart of the fare of class.

# %%
### code here

sns.set_palette('bright')
sns.set_style('whitegrid')

class_fares = titanic.groupby('class')['fare'].mean().reset_index()

sns.barplot(data=class_fares, x='fare', y='class', orient='h')

plt.show()

# %% [markdown]
# ###### 3. Write a Python program to display a bar chart of the fare of class. Use different color for each bar.

# %%
### code here
sns.set_palette('bright')
sns.set_style('whitegrid')

class_fares = titanic.groupby('class')['fare'].mean().reset_index()

colors = ['blue', 'green', 'red']

sns.barplot(data=class_fares, x='class', y='fare', palette=colors)

plt.show()

# %% [markdown]
# ###### 4. Write a Python program to create a pie chart of the fare of class.

# %%
### code here

class_fares = titanic.groupby('class')['fare'].sum()

plt.pie(class_fares, labels=class_fares.index, autopct='%1.1f%%')

plt.axis('equal')

plt.show()

# %% [markdown]
# ######5. Write a Python program to display a count plot of all categorical columns.

# %%
### code here

categorical_cols = ['sex', 'class', 'deck', 'embark_town', 'alone']

for col in categorical_cols:
    sns.countplot(data=titanic, x=col)
    plt.title(f"Count Plot of {col.capitalize()}")
    plt.show()

# %% [markdown]
# ###### 6. Write a Python program to display a factor plot of ( pclass vs embarked). hist (kind = 'count')

# %%
#### code here
sns.factorplot(data=titanic, x='embarked', col='pclass', kind='count')

plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ###### 7. Write a Python programming to display a factor plot of ( pclass vs sex). hist (kind = 'count')

# %%
### code here
sns.factorplot(data=titanic, x='sex', col='pclass', kind='count')

plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ###### 8. Write a Python programming to display a factor plot of ( embarked vs sex). hist (kind = 'count')

# %%
### code here 
sns.factorplot(data=titanic, x='sex', col='embarked', kind='count')

plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ###### 9. Write a Python program to display distribution plot for all numberical columns.

# %%
### code here

num_cols = ['age', 'fare']

for col in num_cols:
    sns.displot(data=titanic, x=col, kde=True)

plt.show()

# %% [markdown]
# ###### 10. Write a Python program to display boxplot of age, pclass and hue = gender.

# %%
### code here

sns.boxplot(data=titanic, x='pclass', y='age', hue='sex')

plt.show()

# %% [markdown]
# ##### Bonus Question

# %% [markdown]
# ##### 1. What are the plots we can create on numerical columns.

# %% [raw]
# ### write here
# 1. Histogram
# 2. Box Plot
# 3. Violin Plot
# 4. Scatter Plot
# 5. Heatmap

# %% [markdown]
# ###### 2. What are the plots we can create on categorical columns.

# %% [raw]
# ### write here
# 1.Bar plot
# 2. Count Plot
# 3. Pie Plot
# 4. Donut Plot
# 5. Heatmap
# 6. Contour plot
